# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode
from fake_useragent import UserAgent
from bs4 import BeautifulSoup
import pandas as pd
import xmltodict
import json
import re

# %%
import scrapy
import re
 
class SpiegelLoginSpider(scrapy.Spider):
    name = 'spiegel'
    allowed_domains = ['gruppenkonto.spiegel.de', 'spigel.de']
    start_urls = ['https://gruppenkonto.spiegel.de/anmelden.html']
    
    def parse(self, response): # 发送Post请求获取Cookies
        form_data = {
            "loginform:loginname": "zjh991600@163.com",
            "loginform:password": "Zjh991600",
        }
        yield scrapy.FormRequest.from_response(response,formdata=form_data,callback=self.after_login)
        
    def after_login(self,response):  # 验证是否请求成功
        print(re.findall('Guten Tag, Jihao Zhang',response.body.decode()))

# %%
import requests
import re
from bs4 import BeautifulSoup

import time
import http.cookiejar as cj

def get_csrf(s):
    response = s.get("https://gruppenkonto.spiegel.de/meinkonto/uebersicht.html", headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    csrf = soup.find('input', attrs={"name": "_csrf"}).get("value")
    return csrf

s = requests.session()
s.verify = False
url_login = 'https://gruppenkonto.spiegel.de/anmelden.html'
url = 'https://www.spiegel.de'

headers = {
    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36"
}

csrf = get_csrf(s)
print(csrf)

formdata = {
    'loginform': 'loginform',
    '_csrf': csrf,
    'loginform:targetUrl':'https://www.spiegel.de/fuermich/',
    'loginform:requestAccessToken':'true',
    'loginform:productid':'',
    'recaptchaTokenHiddenFieldName_loginform':'',
    'loginform:loginname': 'zjh991600@163.com',
    'loginform:password': 'Zjh991600',
    'loginform:loginAutologin_input': 'on',
    'loginform:submit':'',
    'javax.faces.ViewState': 'stateless'
}
r = s.post(url_login, data=formdata, headers=headers, allow_redirects=False)
print(r.status_code)
print(r.headers['Location'])
jar = r.cookies
print(jar)
redirect_URL = r.headers['Location']
headers1 = {
    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36",
    'Referer': 'https://gruppenkonto.spiegel.de/',
    'Host': "www.spiegel.de",
    'Upgrade-Insecure-Requests': '1'
}
responseSecondGet = s.get(redirect_URL, headers=headers1, cookies = jar, allow_redirects=False)
with open('front.html', 'w+', encoding='utf-8') as f:
    f.write(responseSecondGet.text)
next = s.get("https://www.spiegel.de/spiegel/print/d-174544063.html", headers = headers)
with open('next.html', 'w+', encoding='utf-8') as f:
    f.write(next.text)
with open('contacts.html', 'w+', encoding='utf-8') as f:
    f.write(r.text)
response = s.get(url, headers = headers)
with open('spiegel.html', 'w+', encoding='utf-8') as f:
    f.write(response.text)
dic_cookies = requests.utils.dict_from_cookiejar(s.cookies)
print(dic_cookies)
response = s.get("https://www.spiegel.de/spiegel/print/d-174544063.html", headers = headers)
with open('text.html', 'w+', encoding='utf-8') as f:
    f.write(response.text)
# Out:
# D:\Anaconda\lib\site-packages\urllib3\connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gruppenkonto.spiegel.de'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# D:\Anaconda\lib\site-packages\urllib3\connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gruppenkonto.spiegel.de'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# eedb62b4-1092-4535-a037-1f155f17d24e
# D:\Anaconda\lib\site-packages\urllib3\connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gruppenkonto.spiegel.de'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# ...

# %%
from urllib.request import HTTPPasswordMgrWithDefaultRealm, HTTPBasicAuthHandler, build_opener
from urllib.error import URLError

username = 'zjh991600@163.com'
password = 'Zjh991600'
url = 'https://gruppenkonto.spiegel.de/anmelden.html' #假设这是一个需要验证身份的有效网址

p = HTTPPasswordMgrWithDefaultRealm()
p.add_password(None, url, username, password) #添加账户信息，第一个参数realm是与远程服务器相关的域信息，一般没人管它都是写None，后面三个参数分别是 Web服务器、用户名、密码
auth_handler = HTTPBasicAuthHandler(p)
opener = build_opener(auth_handler)

try:
    result = opener.open(url)
    html = result.read().decode('utf-8')
    print(html)
except URLError as e:
    print(e.reason)

# %%
from scrapy import *

def start_requests(self):
    return [Request("https://gruppenkonto.spiegel.de/anmelden.html", callback = self.post_login)]  #重写了爬虫类的方法, 实现了自定义请求, 运行成功后会调用callback回调函数
#FormRequeset
def post_login(self, response):
    print 'Preparing login'
    #下面这句话用于抓取请求网页后返回网页中的_xsrf字段的文字, 用于成功提交表单
    csrf = Selector(response).xpath('//input[@name="_csrf"]/@value').extract()[0]
    print xsrf
    #FormRequeset.from_response是Scrapy提供的一个函数, 用于post表单
    #登陆成功后, 会调用after_login回调函数
    return [FormRequest.from_response(response, 
                        meta = {'cookiejar' : response.meta['cookiejar']}, #注意这里cookie的获取
                        headers = self.headers,
                        formdata = {
                            'loginform': 'loginform',
                            '_csrf': csrf,
                            'loginform:targetUrl':'',
                            'loginform:requestAccessToken':'',
                            'loginform:productid':'',
                            'recaptchaTokenHiddenFieldName_loginform':'',
                            'loginform:loginname': 'zjh991600@163.com',
                            'loginform:password': 'Zjh991600',
                            'loginform:loginAutologin_input': 'on',
                            'loginform:submit':'',
                            'javax.faces.ViewState': 'stateless'
                        },
                        callback = self.after_login
                        )]

# %%
url = "https://www.spiegel.de/politik/ausland/manfred-weber-will-exportstopp-fuer-impfstoffe-wir-brauchen-eu-first-a-5e253453-0002-0001-0000-000176418806"
headers = {
        "User-Agent": UserAgent().chrome
}
request = Request(url, headers=headers)
response = urlopen(request)
print(response.read().decode('utf-8'))
# Out:
# <!doctype html><html lang="de" class="brand-spon">
# <head>
# <title>Manfred Weber will Exportstopp für Impfstoffe: »Wir brauchen ›EU first‹« - DER SPIEGEL</title>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width,initial-scale=1,user-scalable=no">
# <meta name="MSSmartTagsPreventParsing" content="true">
# <meta http-equiv="imagetoolbar" content="no">
# <meta http-equiv="x-ua-compatible" content="IE=Edge">
# <meta name="apple-itunes-app" content="app-id=424881832">
# <link rel="manifest" href="https://www.spiegel.de/public/spon/json/manifest.json">
# <meta name="theme-color" content="#E64415">
# <meta name="google-site-verification" content="lwpSnwoyvMkHS9nHmLBZuYOashAHfooOHSHeA_KS7ek">
# <meta name="robots" content="index, follow, noarchive, noodp, max-snippet:-1, max-image-preview:large, max-video-preview:-1">
# <meta name="Googlebot-News" content="index, follow">
# <meta name="copyright" content="DER SPIEGEL, Hamburg, Germany">
# ...

# %%
import json
import re

import lxml.html
import requests

def scrape_html(article_html: str):
    doc = lxml.html.fromstring(article_html)

    ld_content = doc.xpath('string(//script[@type="application/ld+json"]/text())')
    ld = json.loads(ld_content)
    ld_by_type = {ld_entry['@type']: ld_entry for ld_entry in ld}
    news_ld = ld_by_type['NewsArticle']

    settings = json.loads(doc.xpath('string(//script[@type="application/settings+json"]/text())'))
    info = settings['editorial']['info']

    text_node_selector = \
        'main .word-wrap > p,'  \
        'main .word-wrap > h3, ' \
        'main .word-wrap > ul > li, ' \
        'main .word-wrap > ol > li'
    text_nodes = doc.cssselect(text_node_selector)
    text = re.sub(r'\n+', '\n', '\n'.join([node.text_content() for node in text_nodes])).strip()
    return text
text_url = "https://www.spiegel.de/spiegel/print/d-174544063.html"
headers = {
    "User-Agent": UserAgent().chrome,
    "Cookie": "consentUUID=bd5ef17d-c890-422b-849c-fbe037bac53b; s_ecid=MCMID%7C32765116981730724430833032283937788025; euconsent-v2=CO-WG9mO-WG9mAGABCDEBECgAP_-gEaAI4AYoA3ABxAD0AIbAReAkQBQ4C8wGfANOCAAQCBhoBIAKgAuACGAIKAWkBDYCLwEiAM--JABAALgBfALqAa8pAdAAWABUADIAHAAQAAqABoADyAIgAigBMACeAFwAMQAcwBCACGAFKALEAaIA1QB-gEcANwAegBF4CRAFDgLzAZ8UADAAXAC-ARYAuoBigDXg.YAAAAAAAAAAA; polygon_consent=eyJ2YWx1ZSI6dHJ1ZSwidXBkYXRlZF9hdCI6MTYwNzgzNjg2NX0=; __gads=ID=d88977ad2a16e4f5-222248f235c5007e:T=1608184022:S=ALNI_MbMAIyYP9YzDaCDxeq10NyRvny2OA; _fbp=fb.1.1610614721432.656588985; axd=4249135393269949171; _sp_v1_uid=1:804:b981aef3-8fcd-4886-aa84-cd44faa78fc8; _sp_v1_ss=1:H4sIAAAAAAAAAItWqo5RKimOUbLKK83J0YlRSkVil4AlqmtrlXQGsbJYABZMYxbEAAAA; _sp_v1_opt=1:; _sp_v1_csv=null; _sp_v1_lt=1:; sara_aam_audience_lab_price=segment%3D19570006; sara_aam_uuid=26994352982820014850252578090909175823; iom_consent=0103ff03ff&1615432613022; sara_randomnumber=223; OB-USER-TOKEN=5ea0cbec-3f31-4ffb-91f4-8f670359b5ac; ia-6343437373136323131303=XD:BXnO0Pecfsq178uWwe/NcWvdTHYp6LUGcVWzHFx32t0LGyVxKAWyzpmyBQagXJ2oSjlfYsLPZvSSCd3SRmIpJLIqryBiUq0vCzbDlg/24/E=; s_fid=52175EFBF2C62A43-3155945B723E7698; at_check=true; AMCVS_79655FCF5C1D42160A495E15%40AdobeOrg=1; s_cc=true; POPUPCHECK=1616389543495; accessInfo=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..gUWyDldc7f1loJVeOeva4T110gXzUuc0eXuo5LocAxU; userInfo=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....PTeSzpGJcgUeluro-stMIrvji0AJvls4kU3VBuowB5Q; AMCV_79655FCF5C1D42160A495E15%40AdobeOrg=-1124106680%7CMCIDTS%7C18708%7CMCMID%7C32765116981730724430833032283937788025%7CMCAID%7CNONE%7CMCOPTOUT-1616315113s%7CNONE%7CvVersion%7C5.2.0%7CMCAAMLH-1616912713%7C6%7CMCAAMB-1616912713%7Cj8Odv6LonN4r3an7LhD3WZrU1bUpAkFkkiY1ncBR96t2PTI%7CMCCIDH%7C346804480; adp_segs=e0,e3u,e4u,e3f,e42,e128,e3m,e4y,e13x,e3e,e45,e47,e9,e4z,e3v,e53,e4p,e4r,e18p,e54,ed,e37,e11p,e11g,e46,e3z,e4q,e4d,e40,ey,e3c,e48,e11h,e141,e35,e52,e12a,e4s,e38,e3w,e8,e3i,e2,e3s,eb,e3o,e3b,e14b; ioam2018=001c6cdc1fb775fd95fd5a4b8:1636176059095:1607836859095:.spiegel.de:193:spiegel:err.novalidcode:noevent:1616311988998:ix5bq8; _uetsid=1729e6a08a0311ebbcf11d0383a15634; _uetvid=3a03e590821811ebb0cda9e88be0f14d; mbox=PC#1ec6f235ae60442990c6534b480f033b.37_0#1679556790|session#d775d33a616946418b0480d0b6a6de0b#1616313045; sara_gpv_page=sp.www%20%3E%20issue%20%3E%20%2Fspiegel%2Fprint%2Findex-2020-52.html; adp_pid=BSw-WDB-BDfAWSw3WSRCWsakBsa0WS_ZWsfZESUABifABfrr; s_sq=spiegel.ng.spieg.main%3D%2526c.%2526a.%2526activitymap.%2526page%253Dsp.www%252520%25253E%252520issue%252520%25253E%252520%25252Fspiegel%25252Fprint%25252Findex-2020-52.html%2526link%253DRolex%25252C%252520Gucci%25252C%252520Louis%252520Vuitton%252520Krise%25253F%252520Welche%252520Krise%25253F%2526region%253DInhalt%2526pageIDType%253D1%2526.activitymap%2526.a%2526.c%2526pid%253Dsp.www%252520%25253E%252520issue%252520%25253E%252520%25252Fspiegel%25252Fprint%25252Findex-2020-52.html%2526pidt%253D1%2526oid%253Dhttps%25253A%25252F%25252Fwww.spiegel.de%25252Fwirtschaft%25252Fcorona-das-geschaeft-mit-luxus-laeuft-blendend-krise-welche-krise-%2526ot%253DA; sara_clk_att={%22click_id%22:%22issue:o%20du%20schreckliche>block>topic:wirtschaft>article_teaser>news-m%22%2C%22pos%22:%226:4%22%2C%22target_url%22:%22https://www.spiegel.de/wirtschaft/corona-das-geschaeft-mit-luxus-laeuft-blendend-krise-welche-krise-a-00000000-0002-0001-0000-000174544063?context=issue%22%2C%22headline%22:%22Krise?%20Welche%20Krise?%22%2C%22referrer%22:%22https://www.spiegel.de/spiegel/print/index-2020-52.html%22}; sara_prev_data={%22page%22:{%22article_id%22:%22%22%2C%22channel%22:%22%22}%2C%22performance%22:{%22server_response%22:0%2C%22response_complete%22:46%2C%22page_render%22:20799%2C%22dom_complete%22:20834%2C%22total_load%22:20859%2C%22load_libraries%22:438%2C%22track_pageview%22:523}%2C%22engagement%22:{%22time_first_visible%22:481325%2C%22time_visible%22:24171%2C%22time_hidden%22:485907%2C%22time_active%22:24170%2C%22time_total%22:510078}%2C%22advertising%22:{%22free_adslots_count%22:0}}; sara_user_day=6.f:16.f|4.f:4.f; _sp_v1_data=2:305282:1615432595:0:151:0:151:0:0:_:-1"}
try:
    request = Request(text_url, headers=headers)
    response = urlopen(request)
    info = response.read().decode()
    text = scrape_html(info)
except:
    text = "Nothing"
    pass
print(text)
#print(info)
# Out:
# Die Zürcher Bahnhofstraße ist kein Ort für kleine Geldbeutel. Dicht wie sonst nirgends in Europa drängen sich hier die Luxusboutiquen. Rolex und Prada, Burberry und Hermès. Dazwischen nur ein paar Marken für Normalverdiener: Zara, H & M und Benetton. Doch während sich in deren Filialen an diesem schneegrieseligen Dezembermorgen kaum ein Passant traut, herrscht nebenan großer Andrang. Bei Louis Vuitton stehen schon um elf Uhr morgens ein Dutzend Kunden Schlange und warten bei Temperaturen um den Gefrierpunkt darauf, eingelassen zu werden – was in der Schweiz noch möglich ist, wenn auch einzeln.
# Es ist paradox. Europaweit kämpfen die Läden ums Überleben. Der Deutsche Handelsverband warnt wegen des Shutdowns vor einer »Katastrophe«, sagt 60 Prozent Umsatzminus bei Nicht-Lebensmittelgeschäften voraus, sieht bei Innenstadtläden eine Viertelmillion Jobs in Gefahr. Die teuren Marken indes verkaufen sich derweil, als wäre nichts gewesen.
# ...

# %%
import scrapy
import urllib
from PIL import Image


class SpiegelLoginSpider(scrapy.Spider):
    name = 'spiegel_login'
    allowed_domains = ['douban.com']
#    start_urls = ['http://www.douban.com/']
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2623.221 Safari/537.36 SE 2.X MetaSr 1.0"}

    def start_requests(self):
        '''
        重写start_requests，请求登录页面
        '''
        return [scrapy.FormRequest("https://gruppenkonto.spiegel.de/anmelden.html", headers=self.headers, meta={"cookiejar":1}, callback=self.parse_before_login)]

    def parse_before_login(self, response):
        '''
        登录表单填充，查看验证码
        '''
        print("登录前表单填充")
        captcha_id = response.xpath('//input[@name="captcha-id"]/@value').extract_first()
        captcha_image_url = response.xpath('//img[@id="captcha_image"]/@src').extract_first()
        if captcha_image_url is None:
                print("登录时无验证码")
                formdata = {
                                "source": "index_nav",
                                "form_email": "yanggd1987@163.com",
                                #请填写你的密码
                                "form_password": "********",
                        }
        else:
                print("登录时有验证码")
                save_image_path = "/home/yanggd/python/scrapy/douban/douban/spiders/captcha.jpeg"
                #将图片验证码下载到本地
                urllib.urlretrieve(captcha_image_url, save_image_path)
                #打开图片，以便我们识别图中验证码
                try:
                        im = Image.open('captcha.jpeg')
                        im.show()
                except:
                        pass
		#手动输入验证码
                captcha_solution = raw_input('根据打开的图片输入验证码:')
                formdata = {
                                "source": "None",
                                "redir": "https://www.douban.com",
                                "form_email": "yanggd1987@163.com",
                                #此处请填写密码
                                "form_password": "********",
                                "captcha-solution": captcha_solution,
                                "captcha-id": captcha_id,
                                "login": "登录",
                        }


        print("登录中")
        #提交表单
        return scrapy.FormRequest.from_response(response, meta={"cookiejar":response.meta["cookiejar"]}, headers=self.headers, formdata=formdata, callback=self.parse_after_login)
    def parse_after_login(self, response):
        '''
        验证登录是否成功
        '''
        account = response.xpath('//a[@class="bn-more"]/span/text()').extract_first()
        if account is None:
                print("登录失败")
        else:
                print(u"登录成功,当前账户为 %s" %account)

# %%
#!/usr/bin/env python
# -*- coding:utf-8 -*-
from scrapy.contrib.spiders import CrawlSpider, Rule
from scrapy.selector import Selector
from scrapy.contrib.linkextractors.sgml import SgmlLinkExtractor
from scrapy.http import Request, FormRequest
from zhihu.items import ZhihuItem



class SpiegelSipder(CrawlSpider) :
    name = "spiegel"
    allowed_domains = ["www.spiegel.de"]
    start_urls = [
        "https://www.spiegel.de"
    ]
    rules = (
        Rule(SgmlLinkExtractor(allow = ('/question/\d+#.*?', )), callback = 'parse_page', follow = True),
        Rule(SgmlLinkExtractor(allow = ('/question/\d+', )), callback = 'parse_page', follow = True),
    )
    headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "zh-CN,zh;q=0.9",
    "Connection": "keep-alive",
    "Content-Type":" application/x-www-form-urlencoded",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36",
    "Referer": "https://gruppenkonto.spiegel.de/anmelden.html"
    }

    #重写了爬虫类的方法, 实现了自定义请求, 运行成功后会调用callback回调函数
    def start_requests(self):
        return [Request("https://gruppenkonto.spiegel.de/anmelden.html", meta = {'cookiejar' : 1}, callback = self.post_login)]

    #FormRequeset出问题了
    def post_login(self, response):
        print('Preparing login')
        #下面这句话用于抓取请求网页后返回网页中的_xsrf字段的文字, 用于成功提交表单
        csrf = Selector(response).xpath('//input[@name="_csrf"]/@value').extract()[0]
        print(csrf)
        #FormRequeset.from_response是Scrapy提供的一个函数, 用于post表单
        #登陆成功后, 会调用after_login回调函数
        return [FormRequest.from_response(response,   #"http://www.zhihu.com/login",
                            meta = {'cookiejar' : response.meta['cookiejar']},
                            headers = self.headers,  #注意此处的headers
                            formdata = {
                            'loginform': 'loginform',
                            '_csrf': csrf,
                            'loginform:targetUrl':'',
                            'loginform:requestAccessToken':'',
                            'loginform:productid':'',
                            'recaptchaTokenHiddenFieldName_loginform':'',
                            'loginform:loginname': 'zjh991600@163.com',
                            'loginform:password': 'Zjh991600',
                            'loginform:loginAutologin_input': 'on',
                            'loginform:submit':'',
                            'javax.faces.ViewState': 'stateless'
                            },
                            callback = self.after_login,
                            dont_filter = True
                            )]

    def after_login(self, response) :
        for url in self.start_urls :
            yield self.make_requests_from_url(url)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-57-7524a02da6c4> in <module>()
#       1 #!/usr/bin/env python
#       2 # -*- coding:utf-8 -*-
# ----> 3 from scrapy.contrib.spiders import CrawlSpider, Rule
#       4 from scrapy.selector import Selector
#       5 from scrapy.contrib.linkextractors.sgml import SgmlLinkExtractor
#
# ModuleNotFoundError: No module named 'scrapy.contrib'

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen


class SponCrawler():
    start_url = "http://spiegel.de"
    articles = {}
    visitors = []

    def __init__(self):
        """Grep all current Article URLs"""
        self.page = urlopen(self.start_url)
        self.soup = BeautifulSoup(self.page, 'html.parser')

    def add_visitor(self, visitor):
        """Adds Visitor"""
        self.visitors.append(visitor)

    def parse(self):
        """Parses all urls"""
        all_articles = self.soup.find_all('h2', attrs={'class': 'article-title'})
        for x in all_articles:
            url = x.find('a').get('href')
            if not str.startswith(url, "http"):
                url = self.start_url + url
            self.articles[url] = self.parse_url(url)
        return self.articles

    def parse_url(self, url):
        """Parses URL and calls Spon Visitors and creates new Object"""

        print(url)

        article_soup = BeautifulSoup(urlopen(url), 'html.parser')
        main = article_soup.find('div', attrs={'class': 'spArticleContent'})
        if main is None:
            return

        object = {}
        for x in self.visitors:
            object[type(x).__name__] = (x.parse(main))
        object["url"] = url

        return object

# %%
from datetime import date
import spiegel_scraper as spon

# list all articles from 2020-01-31
archive_entries = spon.archive.by_date(date(2020, 12, 18))
# or, for later replication, retrieve and scrape the html instead
archive_html = spon.archive.html_by_date(date(2020, 12, 18))
archive_entries_from_html = spon.archive.scrape_html(archive_html)

# fetch one article by url
article_url = archive_entries[30]['url']
article = spon.article.by_url(article_url)
# or alternatively using the html
article_html = spon.article.html_by_url(article_url)
article_from_html = spon.article.scrape_html(article_html)

# retrieve all comments for an article
comments = spon.comments.by_article_id(article['id'])

# %%
article_url = archive_entries[31]['url']
article_html1 = spon.article.html_by_url(article_url)
article_from_html1 = spon.article.scrape_html(article_html1)
#article_from_html1['text']
archive_entries
# Out:
# [{'url': 'https://www.spiegel.de/wirtschaft/unternehmen/tesla-muss-rodung-zum-teil-weiter-aussetzen-entscheidung-des-oberverwaltungsgerichts-a-083132f9-1349-4d0b-b106-ea79a2aa7bb6',
#   'headline': 'Entscheidung des Oberverwaltungsgerichts: Tesla muss Rodung zum Teil weiter aussetzen',
#   'is_paid': False,
#   'date_published': datetime.datetime(2020, 12, 18, 23, 17),
#   'channel': 'Wirtschaft'},
#  {'url': 'https://www.spiegel.de/sport/fussball/youssoufa-moukoko-schiesst-rekordtor-borussia-dortmund-verliert-trotzdem-bei-union-a-92a3fd6e-f16a-4228-add6-0499e6f1851c',
#   'headline': 'Fußball-Bundesliga: Moukoko schießt Rekordtor – der BVB verliert trotzdem bei Union',
#   'is_paid': False,
#   'date_published': datetime.datetime(2020, 12, 18, 22, 51),
#   'channel': 'Sport'},
#  {'url': 'https://www.spiegel.de/panorama/schweden-will-untersuchung-des-estonia-wracks-ermoeglichen-a-303b2ecd-e8ad-4ff9-84ee-33e108870c90',
# ...

# %%
class LoginSpider(BaseSpider):
    domain_name = 'spiegel'
    start_urls = ['https://gruppenkonto.spiegel.de/anmelden.html']

    def parse(self, response):
        return [FormRequest.from_response(response,
                formdata={'username': 'john', 'password': 'secret'},
                callback=self.after_login)]

    def after_login(self, response):
        # check login succeed before going on
        if "authentication failed" in response.body:
            self.log("Login failed", level=log.ERROR)
            return

# %%
s = requests.session()
url = 'https://www.spiegel.de'

headers = {
    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36"
}
response = s.get(url, headers = headers)
with open('spiegel.html', 'w+', encoding='utf-8') as f:
    f.write(response.text)
