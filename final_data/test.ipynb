# %%
import pandas as pd

# %%
pd.read_csv("final.csv")
# Out:
#        Unnamed: 0                                 Channel   Epaperkey  \
# 0               0                                 Ausland   SP-1947-1
# 1               1                                 Ausland   SP-1947-1
# 2               2                                 Theater   SP-1947-1
# 3               3                                 Ausland  SP-1947-10
# 4               4                               Forschung  SP-1947-11
# 5               5                                    Film  SP-1947-11
# 6               6                                 Ausland  SP-1947-11
# 7               7                                Panorama  SP-1947-12
# 8               8                                  Kultur  SP-1947-12
# 9               9                                  Presse  SP-1947-13
# 10             10                                 Ausland  SP-1947-13
# 11             11                                 Ausland  SP-1947-14
# ...
