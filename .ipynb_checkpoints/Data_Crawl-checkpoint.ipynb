# %% [markdown]
# # 毕业设计：基于标题检索和语料库分析的《明镜》周刊（1947-2020）涉华报道研究 —— 数据爬虫

# %% [markdown]
# ## 导入所有需要用到的模块

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode
from fake_useragent import UserAgent
from bs4 import BeautifulSoup
import pandas as pd
import xmltodict
import json
import re

# %% [markdown]
# ## 创建文章数据基础链接

# %%
base_url = "https://joda.spiegel.de/joda/spon/search?s=China&p=SP&f=kopftext&page={}&max=100&from=19000101&to=20201231&plus=0"

# %% [markdown]
# ## 建立data列表用于存储文章数据

# %%
data = list()

# %% [markdown]
# ## 爬取基于标题检索的文章数据

# %%
for page in range(11):
    print("正在下载第" + str(page) + "页")
    url = base_url.format(page)

    headers = {
        "User-Agent": UserAgent().chrome
    }

    request = Request(url, headers=headers)
    response = urlopen(request)
    xml = response.read()
    convert = xmltodict.parse(xml, encoding='utf-8')
    jsonstr = json.dumps(convert, indent=4)
    tmpDict = json.loads(jsonstr)
    data += tmpDict['search-result']['hits']['dokument']
# Out:
# 正在下载第0页
# 正在下载第1页
# 正在下载第2页
# 正在下载第3页
# 正在下载第4页
# 正在下载第5页
# 正在下载第6页
# 正在下载第7页
# 正在下载第8页
# 正在下载第9页
# 正在下载第10页

# %%
data
# Out:
# [{'id': '174544063',
#   'spiegelPlusId': '174556841',
#   'slug': 'SP-2020-052-85959',
#   'score': '5.286109',
#   'dokname': 'CODESCO-SP-2020-052-85959',
#   'ueberschrift': 'Man gönnt sich wieder was',
#   'oberzeile': 'Konsum',
#   'abstrakt': 'Der Handel leidet, doch der Luxus boomt',
#   'autoren': {'autor': [{'name': 'Simon Book'}, {'name': 'Kristina Gnirke'}]},
#   'vorspann': 'Krise? Welche Krise? Im Luxussegment laufen die Geschäfte vielerorts blendend. Vor allem dank China. Aber auch die Deutschen shoppen gern teuer.',
#   'teaserText': 'Krise? Welche Krise? Im Luxussegment laufen die Geschäfte vielerorts blendend. Vor allem dank China. Aber auch die Deutschen shoppen gern teuer.; Der Handel leidet, doch der Luxus boomt; Die Zürcher Bahnhofstraße ist kein Ort für kleine Geldbeutel.…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '52',
#   'epaperkey': 'SP-2020-52',
#   'rubrik': 'Wirtschaft',
#   'channel': 'Wirtschaft',
#   'erscheinungsdatum': '19.12.2020',
#   'seite': '82',
#   'wordcount': '1366',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5004911',
#      '@name': 'Wirtschaft/Industrie/Branchen/Luxuswaren, Konsumgüter',
#      '@kuerzel': 'W/6/Bra/Luw'},
#     {'@id': '7008276',
#      '@name': 'Wirtschaft/Handel/Verbraucher/Allgemeines und Sonstiges',
#      '@kuerzel': 'W/5/Verb/So'}],
#    'eigenname': {'@id': '8683183', '@name': 'Corona-Krise'},
#    'geo': [{'@id': '6000176', '@name': 'Internationales', '@kuerzel': 'I'},
#     {'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '174419239',
#   'slug': 'SP-2020-051-1609237748659688',
#   'score': '6.6307707',
#   'dokname': 'CODESCO-SP-2020-051-1609237748659688',
#   'ueberschrift': 'Betr.: China',
#   'oberzeile': 'Hausmitteilung',
#   'teaserText': 'Seit acht Jahren führt Xi Jinping die KP Chinas, und genauso lange hat Bernhard Zand für den SPIEGEL aus Peking berichtet. Vor seinem Abschied sind Zand und seine Mitarbeiterin Wu Dandan noch einmal von Nord nach Süd durch das Land gereist. »Die…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '51',
#   'epaperkey': 'SP-2020-51',
#   'rubrik': 'Hausmitteilung',
#   'channel': 'Hausmitteilung',
#   'erscheinungsdatum': '12.12.2020',
#   'seite': '5',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1'},
#  {'id': '174419284',
#   'spiegelPlusId': '174421846',
#   'slug': 'SP-2020-051-85687',
#   'score': '5.560302',
#   'dokname': 'CODESCO-SP-2020-051-85687',
#   'ueberschrift': '»Viel Erfolg weiterhin«',
#   'oberzeile': 'Wirecard',
#   'abstrakt': 'Wie die Bundesregierung den Konzern bei der Chinaexpansion umgarnte',
#   'autoren': {'autor': [{'name': 'Tim Bartz'},
#     {'name': 'David Böcking'},
#     {'name': 'Martin Hesse'},
#     {'name': 'Gerald Traufetter'}]},
#   'vorspann': 'Vertrauliche Dokumente belegen, dass sich die Bundesregierung stärker als bekannt für die Expansion des Finanzkonzerns nach China engagierte.',
#   'teaserText': 'Vertrauliche Dokumente belegen, dass sich die Bundesregierung stärker als bekannt für die Expansion des Finanzkonzerns nach China engagierte.; Wie die Bundesregierung den Konzern bei der Chinaexpansion umgarnte; Was den deutschen Diplomaten so in…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '51',
#   'epaperkey': 'SP-2020-51',
#   'rubrik': 'Wirtschaft',
#   'channel': 'Wirtschaft',
#   'erscheinungsdatum': '12.12.2020',
#   'seite': '64',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': {'@id': '7008302',
#     '@name': 'Wirtschaft/Unternehmen, Betriebe/Unternehmer, Arbeitgeber, Manager/Politik',
#     '@kuerzel': 'W/7/Unt/Pol'},
#    'firma': {'@id': '7279797', '@name': 'Wirecard'},
#    'geo': [{'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '174316816',
#   'slug': 'SP-2020-050-85261',
#   'score': '6.5850024',
#   'dokname': 'CODESCO-SP-2020-050-85261',
#   'ueberschrift': 'Neuer Kinoboom in Asien',
#   'oberzeile': 'Filmgeschäft',
#   'abstrakt': 'In Asien boomt das Kino trotz Corona',
#   'autoren': {'autor': {'name': 'LOB,'}},
#   'vorspann': 'Blockbuster in China und Japan machen auch Hollywood wieder Mut.',
#   'teaserText': 'Blockbuster in China und Japan machen auch Hollywood wieder Mut.; In Asien boomt das Kino trotz Corona; • Seit einiger Zeit gehen Experten davon aus, dass der amerikanische Kinomarkt – bislang der größte der Welt – vom chinesischen…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '50',
#   'epaperkey': 'SP-2020-50',
#   'rubrik': 'Meldung Kultur',
#   'channel': 'Meldung Kultur',
#   'erscheinungsdatum': '05.12.2020',
#   'seite': '118',
#   'wordcount': '273',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5000305',
#      '@name': 'Film/Finanzen/Umsätze',
#      '@kuerzel': 'Fi/4/Ums'},
#     {'@id': '5000306', '@name': 'Film/Handel', '@kuerzel': 'Fi/5'}],
#    'geo': [{'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000154', '@name': 'Japan', '@kuerzel': 'Ja'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '174316771',
#   'spiegelPlusId': '174320903',
#   'slug': 'SP-2020-050-85360',
#   'score': '4.7059526',
#   'dokname': 'CODESCO-SP-2020-050-85360',
#   'ueberschrift': '»Es muss ein Signal an Iran geben«',
#   'oberzeile': 'Diplomatie',
#   'abstrakt': 'Außenminister Maas fordert ein »Nuklearabkommen Plus« mit Iran',
#   'autoren': {'autor': [{'name': 'Interview: Christiane Hoffmann'},
#     {'name': 'Martin Knobbe'}]},
#   'vorspann': 'Außenminister Heiko Maas (SPD) wird das Verhältnis zur neuen US-Regierung gestalten müssen. Was also ist möglich – in Sachen China, Nahost und auch Nord Stream 2?',
#   'teaserText': 'Außenminister Heiko Maas (SPD) wird das Verhältnis zur neuen US-Regierung gestalten müssen. Was also ist möglich – in Sachen China, Nahost und auch Nord Stream 2?; Außenminister Maas fordert ein »Nuklearabkommen Plus« mit Iran;…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '50',
#   'epaperkey': 'SP-2020-50',
#   'rubrik': 'Interview Deutschland',
#   'channel': 'Interview Deutschland',
#   'erscheinungsdatum': '05.12.2020',
#   'seite': '30',
#   'wordcount': '2327',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5002636',
#      '@name': 'Militär/Auslandsbeziehungen',
#      '@kuerzel': 'M/34'},
#     {'@id': '5002930',
#      '@name': 'Politik/Außenpolitik/Linie',
#      '@kuerzel': 'P/34/Lin'},
#     {'@id': '5002937',
#      '@name': 'Politik/Außenpolitik/Beziehungen zu Staaten/Allgemeines und Sonstiges',
#      '@kuerzel': 'P/34/Staa/So'}],
#    'person': [{'@id': '21144',
#      '@name': 'Biden, Joe',
#      '@vorname': 'Joe',
#      '@nachname': 'Biden'},
#     {'@id': '149900',
#      '@name': 'Maas, Heiko',
#      '@vorname': 'Heiko',
#      '@nachname': 'Maas'}],
#    'geo': [{'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000079', '@name': 'Nahost', '@kuerzel': 'NaO'},
#     {'@id': '6000150', '@name': 'Iran', '@kuerzel': 'Irn'},
#     {'@id': '6000152', '@name': 'Israel', '@kuerzel': 'Isr'},
#     {'@id': '6000181', '@name': 'Frankreich', '@kuerzel': 'Fr'},
#     {'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000232', '@name': 'Afghanistan', '@kuerzel': 'Afg'},
#     {'@id': '6000276',
#      '@name': 'North Atlantic Treaty Organization (NATO)',
#      '@kuerzel': 'Nato'},
#     {'@id': '6000361', '@name': 'Europäische Union (EU)', '@kuerzel': 'EU'},
#     {'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000079', '@name': 'Nahost', '@kuerzel': 'NaO'},
#     {'@id': '6000150', '@name': 'Iran', '@kuerzel': 'Irn'},
#     {'@id': '6000152', '@name': 'Israel', '@kuerzel': 'Isr'},
#     {'@id': '6000181', '@name': 'Frankreich', '@kuerzel': 'Fr'},
#     {'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000232', '@name': 'Afghanistan', '@kuerzel': 'Afg'},
#     {'@id': '6000276',
#      '@name': 'North Atlantic Treaty Organization (NATO)',
#      '@kuerzel': 'Nato'},
#     {'@id': '6000361', '@name': 'Europäische Union (EU)', '@kuerzel': 'EU'}]}},
#  {'id': '174103641',
#   'slug': 'SP-2020-048-84667',
#   'score': '6.6307707',
#   'dokname': 'CODESCO-SP-2020-048-84667',
#   'ueberschrift': 'Aufrüsten gegen China?',
#   'oberzeile': 'Supermächte',
#   'abstrakt': 'USA plant stärkere Marine-Präsenz gegen China',
#   'autoren': {'autor': {'name': 'BZA'}},
#   'teaserText': 'USA plant stärkere Marine-Präsenz gegen China; • Die US-Streitkräfte erwägen, ein weiteres Marinekommando einzurichten, um Chinas militärischem Einfluss im Westpazifik entgegenzutreten. »Wir wollen eine neue Flotte aufstellen«, sagte…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '48',
#   'epaperkey': 'SP-2020-48',
#   'rubrik': 'Meldung Ausland',
#   'channel': 'Meldung Ausland',
#   'erscheinungsdatum': '21.11.2020',
#   'seite': '81',
#   'wordcount': '265',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '7009185',
#      '@name': 'Militär/Seestreitkräfte/Truppenteile',
#      '@kuerzel': 'M/222/Trt'},
#     {'@id': '5002636',
#      '@name': 'Militär/Auslandsbeziehungen',
#      '@kuerzel': 'M/34'}],
#    'geo': [{'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000276',
#      '@name': 'North Atlantic Treaty Organization (NATO)',
#      '@kuerzel': 'Nato'}]}},
#  {'id': '174103643',
#   'spiegelPlusId': '174156639',
#   'slug': 'SP-2020-048-84669',
#   'score': '4.5080476',
#   'dokname': 'CODESCO-SP-2020-048-84669',
#   'ueberschrift': 'Das Menschheitsprojekt',
#   'oberzeile': 'Geopolitik',
#   'abstrakt': 'Um die Verteilung von Corona-Impfstoffen ist ein hitziger Wettkampf entbrannt – zum Nachteil armer Länder',
#   'autoren': {'autor': [{'name': 'Alexander Chernyshev'},
#     {'name': 'Georg Fahrion'},
#     {'name': 'Jens Glüsing'},
#     {'name': 'Laura Höflinger'},
#     {'name': 'Fritz Schaap'}]},
#   'vorspann': 'Die ersten Corona-Vakzinen stehen vor der Zulassung, reiche Staaten haben sich schon längst Milliarden Dosen gesichert. Ärmere Länder laufen Gefahr, sich von Mächten wie China oder Russland abhängig zu machen.',
#   'teaserText': 'Die ersten Corona-Vakzinen stehen vor der Zulassung, reiche Staaten haben sich schon längst Milliarden Dosen gesichert. Ärmere Länder laufen Gefahr, sich von Mächten wie China oder Russland abhängig zu machen.; Um die Verteilung von…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '48',
#   'epaperkey': 'SP-2020-48',
#   'rubrik': 'Ausland Coronakrise',
#   'channel': 'Ausland Coronakrise',
#   'erscheinungsdatum': '21.11.2020',
#   'seite': '82',
#   'wordcount': '2669',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5001440',
#      '@name': 'Forschung, Wissenschaft/Medizin/Präventivmedizin',
#      '@kuerzel': 'FW/100/Prä'},
#     {'@id': '5002930',
#      '@name': 'Politik/Außenpolitik/Linie',
#      '@kuerzel': 'P/34/Lin'}],
#    'eigenname': {'@id': '8683183', '@name': 'Corona-Krise'},
#    'geo': [{'@id': '6000176', '@name': 'Internationales', '@kuerzel': 'I'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000176', '@name': 'Internationales', '@kuerzel': 'I'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000176', '@name': 'Internationales', '@kuerzel': 'I'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '173743593',
#   'spiegelPlusId': '173746046',
#   'slug': 'SP-2020-045-83300',
#   'score': '5.560302',
#   'dokname': 'CODESCO-SP-2020-045-83300',
#   'ueberschrift': 'Globaler Kampf',
#   'oberzeile': 'Olympia',
#   'abstrakt': 'Japans Nationalisten wollen die Spiele in Tokio retten',
#   'autoren': {'autor': {'name': 'Felix Lill'}},
#   'vorspann': 'Japan ringt um die Spiele im kommenden Jahr. Für die Nationalisten geht es um alles: den Gegner China, die Kriegsschuld, die Aufrüstung.',
#   'teaserText': 'Japan ringt um die Spiele im kommenden Jahr. Für die Nationalisten geht es um alles: den Gegner China, die Kriegsschuld, die Aufrüstung.; Japans Nationalisten wollen die Spiele in Tokio retten; Yoshiro Mori, Cheforganisator der Olympischen Spiele in…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '45',
#   'epaperkey': 'SP-2020-45',
#   'rubrik': 'Sport',
#   'channel': 'Sport',
#   'erscheinungsdatum': '30.10.2020',
#   'seite': '103',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5003069',
#      '@name': 'Politik/Innenpolitik/Nationalismus',
#      '@kuerzel': 'P/41/Nat'},
#     {'@id': '5004005',
#      '@name': 'Sport/Olympische Spiele/Olympische Sommerspiele/Allgemeines und Sonstiges',
#      '@kuerzel': 'S/396/Som/So'}],
#    'eigenname': {'@id': '7677453', '@name': 'Tokio 2021'},
#    'geo': {'@id': '6000154', '@name': 'Japan', '@kuerzel': 'Ja'}}},
#  {'id': '173743577',
#   'spiegelPlusId': '173776778',
#   'slug': 'SP-2020-045-83236',
#   'score': '4.604875',
#   'dokname': 'CODESCO-SP-2020-045-83236',
#   'ueberschrift': 'Die Teilung der Welt',
#   'oberzeile': 'Technologie',
#   'abstrakt': 'Die USA und China ringen um die Vorherrschaft in der digitalen Welt',
#   'autoren': {'autor': [{'name': 'Markus Böhm'},
#     {'name': 'Georg Fahrion'},
#     {'name': 'Judith Horchert'},
#     {'name': 'Matthias Kremp'},
#     {'name': 'Marcel Rosenbach'},
#     {'name': 'Stefan Schultz'},
#     {'name': 'Bernhard Zand'}]},
#   'vorspann': 'Auf kein Land hat sich der US-Präsident so eingeschossen wie auf China. Und selbst wenn er die Wahl verlieren sollte: Der Kampf um die digitale Vorherrschaft im 21. Jahrhundert wird das Verhältnis zwischen den Supermächten weit über die Ära Trump hinaus bestimmen.',
#   'teaserText': 'Auf kein Land hat sich der US-Präsident so eingeschossen wie auf China. Und selbst wenn er die Wahl verlieren sollte: Der Kampf um die digitale Vorherrschaft im 21. Jahrhundert wird das Verhältnis zwischen den Supermächten weit über die Ära Trump…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '45',
#   'epaperkey': 'SP-2020-45',
#   'rubrik': 'Wirtschaft',
#   'channel': 'Wirtschaft',
#   'erscheinungsdatum': '30.10.2020',
#   'seite': '78',
#   'wordcount': '3031',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5002938',
#      '@name': 'Politik/Außenpolitik/Beziehungen zu Staaten/Zwischenfälle',
#      '@kuerzel': 'P/34/Staa/Zw'},
#     {'@id': '5004740',
#      '@name': 'Wirtschaft/Handel/Außenhandel/Außenhandelsbeziehungen',
#      '@kuerzel': 'W/5/Auss/Bez'},
#     {'@id': '5004340',
#      '@name': 'Wirtschaft/Gesamtwirtschaft/Wettbewerbsfähigkeit',
#      '@kuerzel': 'W/12/Wef'},
#     {'@id': '7021583',
#      '@name': 'Wirtschaft/Gesamtwirtschaft/Digitale Wirtschaft',
#      '@kuerzel': 'W/12/Dig'},
#     {'@id': '5004738',
#      '@name': 'Wirtschaft/Handel/Außenhandel/Politik',
#      '@kuerzel': 'W/5/Auss/Pol'}],
#    'person': {'@id': '244584',
#     '@name': 'Trump, Donald [Präsident/geb.1946]',
#     '@vorname': 'Donald',
#     '@nachname': 'Trump',
#     '@zusatz': 'Präsident/geb.1946'},
#    'geo': [{'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000176', '@name': 'Internationales', '@kuerzel': 'I'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000176', '@name': 'Internationales', '@kuerzel': 'I'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '173654754',
#   'spiegelPlusId': '173672040',
#   'slug': 'SP-2020-044-83148',
#   'score': '4.4152083',
#   'dokname': 'CODESCO-SP-2020-044-83148',
#   'ueberschrift': '»Brutal gefährlich«',
#   'oberzeile': 'Demokratie',
#   'abstrakt': 'Die Pandemie krempelt das politische System der Republik um',
#   'autoren': {'autor': [{'name': 'Julia Amalia Heyer'},
#     {'name': 'Christoph Hickmann'},
#     {'name': 'Christiane Hoffmann'},
#     {'name': 'Dirk Kurbjuweit'},
#     {'name': 'Timo Lehmann'},
#     {'name': 'Ann-Katrin Müller'},
#     {'name': 'Jonas Schaible'}]},
#   'vorspann': 'Die Pandemie fordert das politische System heraus. Die Parteiarbeit funktioniert nicht wie sonst, Regierungen und Parlamente rangeln um Einfluss. Und der Blick nach China wirft zu Beginn der zweiten Corona-Welle die Frage nach den Grenzen der Liberalität auf.',
#   'teaserText': 'Die Pandemie fordert das politische System heraus. Die Parteiarbeit funktioniert nicht wie sonst, Regierungen und Parlamente rangeln um Einfluss. Und der Blick nach China wirft zu Beginn der zweiten Corona-Welle die Frage nach den Grenzen der…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '44',
#   'epaperkey': 'SP-2020-44',
#   'rubrik': 'Deutschland Coronakrise',
#   'channel': 'Deutschland Coronakrise',
#   'erscheinungsdatum': '24.10.2020',
#   'seite': '28',
#   'wordcount': '2490',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5001801',
#      '@name': 'Forschung, Wissenschaft/Politologie/Kultur',
#      '@kuerzel': 'FW/106/Kul'},
#     {'@id': '7020892',
#      '@name': 'Politik/Regierung/Beziehungen/Exekutive-Legislative-Beziehungen',
#      '@kuerzel': 'P/45/Bez/Leg'},
#     {'@id': '5001795',
#      '@name': 'Forschung, Wissenschaft/Politologie/Demokratie',
#      '@kuerzel': 'FW/106/Dem'},
#     {'@id': '7007580',
#      '@name': 'Politik/Parteien/Einzelne Parteien/Parteitage',
#      '@kuerzel': 'P/40/E/Pat'}],
#    'person': [{'@id': '174382',
#      '@name': 'Nolte, Paul [Historiker]',
#      '@vorname': 'Paul',
#      '@nachname': 'Nolte',
#      '@zusatz': 'Historiker'},
#     {'@id': '8497464',
#      '@name': 'Richter, Hedwig',
#      '@vorname': 'Hedwig',
#      '@nachname': 'Richter'}],
#    'firma': {'@id': '7163097', '@name': 'CDU'},
#    'eigenname': {'@id': '8683183', '@name': 'Corona-Krise'},
#    'geo': [{'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'}]}},
#  {'id': '173100131',
#   'spiegelPlusId': '173101324',
#   'slug': 'SP-2020-039-81328',
#   'score': '4.3261166',
#   'dokname': 'CODESCO-SP-2020-039-81328',
#   'ueberschrift': 'Pest und Weltmarkt',
#   'oberzeile': 'Landwirtschaft',
#   'abstrakt': 'Die Export-abhängigkeit der Fleischindustrie behindert einen Neuanfang',
#   'autoren': {'autor': [{'name': 'Andreas Flammang'},
#     {'name': 'Michaela Schießl'}]},
#   'vorspann': 'Ein paar infizierte Wildsauen sorgen dafür, dass Deutschlands Fleischindustrie keine Schweine mehr nach China liefern darf. Der Bann zeigt, wie sehr die Branche inzwischen vom Export abhängt – und wie kaputt das Mastsystem ist.',
#   'teaserText': 'Ein paar infizierte Wildsauen sorgen dafür, dass Deutschlands Fleischindustrie keine Schweine mehr nach China liefern darf. Der Bann zeigt, wie sehr die Branche inzwischen vom Export abhängt – und wie kaputt das Mastsystem ist.; Die…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '39',
#   'epaperkey': 'SP-2020-39',
#   'rubrik': 'Wirtschaft',
#   'channel': 'Wirtschaft',
#   'erscheinungsdatum': '19.09.2020',
#   'seite': '64',
#   'wordcount': '1917',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5002301',
#      '@name': 'Forschung, Wissenschaft/Biologie/Zoologie/Tierschutz/Misshandlungen',
#      '@kuerzel': 'FW/94/Zoo/Tisch/Mis'},
#     {'@id': '5004506',
#      '@name': 'Wirtschaft/Ernährung/Landwirtschaft/Viehzucht',
#      '@kuerzel': 'W/3/Lan/Viz'},
#     {'@id': '5004479',
#      '@name': 'Wirtschaft/Ernährung/Export, Import',
#      '@kuerzel': 'W/3/Exp'},
#     {'@id': '5004482',
#      '@name': 'Wirtschaft/Ernährung/Fleisch',
#      '@kuerzel': 'W/3/Fle'},
#     {'@id': '7008320',
#      '@name': 'Wirtschaft/Dienstleistung/Handwerk/Berufe/Fleischer',
#      '@kuerzel': 'W/9/Haw/Ber/Fle'}],
#    'firma': {'@id': '7085198', '@name': 'Tönnies'},
#    'geo': [{'@id': '6000176', '@name': 'Internationales', '@kuerzel': 'I'},
#     {'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '172993210',
#   'spiegelPlusId': '172995181',
#   'slug': 'SP-2020-038-80844',
#   'score': '5.8142033',
#   'dokname': 'CODESCO-SP-2020-038-80844',
#   'ueberschrift': 'Guttenberg lobbyierte in China',
#   'oberzeile': 'Wirecard-Skandal',
#   'autoren': {'autor': [{'name': 'GT,'}, {'name': 'MGB,'}, {'name': 'SVE,'}]},
#   'vorspann': 'Ex-Verteidigungsminister arrangierte Treffen von Managern in der Botschaft',
#   'teaserText': 'Ex-Verteidigungsminister arrangierte Treffen von Managern in der Botschaft; • Ex-Verteidigungsminister Karl-Theodor zu Guttenberg setzte sich als Lobbyist früher für den Finanzkonzern Wirecard ein als bislang bekannt. Schon ein Jahr bevor sich…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '38',
#   'epaperkey': 'SP-2020-38',
#   'rubrik': 'Meldung Wirtschaft',
#   'channel': 'Meldung Wirtschaft',
#   'erscheinungsdatum': '12.09.2020',
#   'seite': '54',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '7008302',
#      '@name': 'Wirtschaft/Unternehmen, Betriebe/Unternehmer, Arbeitgeber, Manager/Politik',
#      '@kuerzel': 'W/7/Unt/Pol'},
#     {'@id': '5003419',
#      '@name': 'Politik/Parlament/Lobby',
#      '@kuerzel': 'P/54/Lob'}],
#    'person': {'@id': '7621953',
#     '@name': 'Guttenberg, Karl-Theodor zu [Freiherr/geb.1971]',
#     '@vorname': 'Karl-Theodor zu',
#     '@nachname': 'Guttenberg',
#     '@zusatz': 'Freiherr/geb.1971'},
#    'firma': {'@id': '7279797', '@name': 'Wirecard'},
#    'geo': [{'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '172378520',
#   'spiegelPlusId': '172382878',
#   'slug': 'SP-2020-033-78955',
#   'score': '5.4197397',
#   'dokname': 'CODESCO-SP-2020-033-78955',
#   'ueberschrift': 'Der »Sputnik-Moment«',
#   'oberzeile': 'Geopolitik',
#   'abstrakt': 'Russland und China wollen die Jagd auf einen Impfstoff mit fragwürdigen Methoden gewinnen',
#   'autoren': {'autor': [{'name': 'Alexander Chernyshev'},
#     {'name': 'Wu Dandan'},
#     {'name': 'Georg Fahrion'},
#     {'name': 'Christina Hebel'},
#     {'name': 'Laura Höflinger'},
#     {'name': 'Bernhard Zand'}]},
#   'vorspann': 'Russland, China und Indien arbeiten mit Hochdruck an einem Impfstoff. Testphasen werden übersprungen, Forscher probieren Vakzine an sich selbst und an Soldaten aus.',
#   'teaserText': 'Russland, China und Indien arbeiten mit Hochdruck an einem Impfstoff. Testphasen werden übersprungen, Forscher probieren Vakzine an sich selbst und an Soldaten aus.; Russland und China wollen die Jagd auf einen Impfstoff mit fragwürdigen Methoden…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '33',
#   'epaperkey': 'SP-2020-33',
#   'rubrik': 'Ausland Coronakrise',
#   'channel': 'Ausland Coronakrise',
#   'erscheinungsdatum': '08.08.2020',
#   'seite': '86',
#   'wordcount': '1624',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': {'@id': '5001440',
#     '@name': 'Forschung, Wissenschaft/Medizin/Präventivmedizin',
#     '@kuerzel': 'FW/100/Prä'},
#    'eigenname': {'@id': '8683183', '@name': 'Corona-Krise'},
#    'geo': [{'@id': '6000061', '@name': 'Russland', '@kuerzel': 'Rus'},
#     {'@id': '6000177', '@name': 'Indien', '@kuerzel': 'Ind'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000061', '@name': 'Russland', '@kuerzel': 'Rus'},
#     {'@id': '6000177', '@name': 'Indien', '@kuerzel': 'Ind'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '172270239',
#   'spiegelPlusId': '172345411',
#   'slug': 'SP-2020-032-78487',
#   'score': '5.15891',
#   'dokname': 'CODESCO-SP-2020-032-78487',
#   'ueberschrift': 'Spiel mit der Bombe',
#   'oberzeile': 'Atomwaffen',
#   'abstrakt': '30 Jahre nach dem Ende des Kalten Krieges wird ein Nuklearkonflikt wieder wahrscheinlicher',
#   'autoren': {'autor': [{'name': 'Christian Esch'},
#     {'name': 'Dietmar Pieper'},
#     {'name': 'Alexander Sarovic'},
#     {'name': 'Bernhard Zand'}]},
#   'vorspann': '75 Jahre nach den ersten und bisher einzigen Atombombenangriffen rüsten die USA, Russland und China erneut auf. Der Einsatz von Nuklearwaffen wird wahrscheinlicher.',
#   'teaserText': '75 Jahre nach den ersten und bisher einzigen Atombombenangriffen rüsten die USA, Russland und China erneut auf. Der Einsatz von Nuklearwaffen wird wahrscheinlicher.; 30 Jahre nach dem Ende des Kalten Krieges wird ein Nuklearkonflikt wieder…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '32',
#   'epaperkey': 'SP-2020-32',
#   'rubrik': 'Ausland',
#   'channel': 'Ausland',
#   'erscheinungsdatum': '01.08.2020',
#   'seite': '76',
#   'wordcount': '2542',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': {'@id': '5002594',
#     '@name': 'Militär/Waffen, Gerät/Atomwaffen/Sonstiges',
#     '@kuerzel': 'M/244/Ato/So'},
#    'geo': [{'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000061', '@name': 'Russland', '@kuerzel': 'Rus'},
#     {'@id': '6000176', '@name': 'Internationales', '@kuerzel': 'I'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000061', '@name': 'Russland', '@kuerzel': 'Rus'},
#     {'@id': '6000176', '@name': 'Internationales', '@kuerzel': 'I'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000061', '@name': 'Russland', '@kuerzel': 'Rus'},
#     {'@id': '6000176', '@name': 'Internationales', '@kuerzel': 'I'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '172178883',
#   'spiegelPlusId': '172180882',
#   'slug': 'SP-2020-031-78403',
#   'score': '6.3887725',
#   'dokname': 'CODESCO-SP-2020-031-78403',
#   'ueberschrift': 'Sanktionen gegen ausländische Hacker',
#   'oberzeile': 'Europäische Union',
#   'autoren': {'autor': {'name': 'MBE'}},
#   'vorspann': 'Mutmaßlichen Gegnern aus Russland und China drohen Einreiseverbote.',
#   'teaserText': 'Mutmaßlichen Gegnern aus Russland und China drohen Einreiseverbote.; • Die EU will Hacker aus Russland und China mit Sanktionen belegen. Auf einer vertraulichen Liste, die am Mittwoch von den Botschaftern der EU-Staaten abgesegnet wurde,…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '31',
#   'epaperkey': 'SP-2020-31',
#   'rubrik': 'Meldung Deutschland',
#   'channel': 'Meldung Deutschland',
#   'erscheinungsdatum': '25.07.2020',
#   'seite': '22',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5001114',
#      '@name': 'Technik/Informationstechnik/Sicherheit',
#      '@kuerzel': 'T/75/Sich'},
#     {'@id': '5004733',
#      '@name': 'Wirtschaft/Handel/Außenhandel/Boykott',
#      '@kuerzel': 'W/5/Auss/Boy'},
#     {'@id': '5002925',
#      '@name': 'Politik/Außenpolitik/Grenzen',
#      '@kuerzel': 'P/34/Gre'},
#     {'@id': '7009129',
#      '@name': 'Politik/Spionage, Geheimdienste/Angestellte',
#      '@kuerzel': 'P/48/Ang'},
#     {'@id': '5003299',
#      '@name': 'Politik/Spionage, Geheimdienste/Fälle (Geo: beteiligte Länder)',
#      '@kuerzel': 'P/48/Fäl'}],
#    'firma': {'@id': '7206461', '@name': 'GRU (Geo: Rus)'},
#    'geo': [{'@id': '6000061', '@name': 'Russland', '@kuerzel': 'Rus'},
#     {'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000361', '@name': 'Europäische Union (EU)', '@kuerzel': 'EU'}]}},
#  {'id': '171773560',
#   'spiegelPlusId': '171775192',
#   'slug': 'SP-2020-027-77086',
#   'score': '5.8644953',
#   'dokname': 'CODESCO-SP-2020-027-77086',
#   'ueberschrift': 'Herkules gegen Goliath',
#   'oberzeile': 'Analyse',
#   'abstrakt': 'Die gefährliche Eskalation zwischen den Nuklearmächten Indien und China',
#   'autoren': {'autor': [{'name': 'Laura Höflinger'},
#     {'name': 'Bernhard Zand'}]},
#   'vorspann': 'Wie Indien und China in Asien um Einfluss ringen – und die USA profitieren könnten',
#   'teaserText': 'Wie Indien und China in Asien um Einfluss ringen – und die USA profitieren könnten; Die gefährliche Eskalation zwischen den Nuklearmächten Indien und China; Es gibt vieles, was China und Indien verbindet. Beide eint der Glaube, dass die Welt…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '27',
#   'epaperkey': 'SP-2020-27',
#   'rubrik': 'Kolumne Ausland',
#   'channel': 'Kolumne Ausland',
#   'erscheinungsdatum': '27.06.2020',
#   'seite': '82',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5002925',
#      '@name': 'Politik/Außenpolitik/Grenzen',
#      '@kuerzel': 'P/34/Gre'},
#     {'@id': '5002636',
#      '@name': 'Militär/Auslandsbeziehungen',
#      '@kuerzel': 'M/34'},
#     {'@id': '5002938',
#      '@name': 'Politik/Außenpolitik/Beziehungen zu Staaten/Zwischenfälle',
#      '@kuerzel': 'P/34/Staa/Zw'},
#     {'@id': '5002937',
#      '@name': 'Politik/Außenpolitik/Beziehungen zu Staaten/Allgemeines und Sonstiges',
#      '@kuerzel': 'P/34/Staa/So'},
#     {'@id': '5002930',
#      '@name': 'Politik/Außenpolitik/Linie',
#      '@kuerzel': 'P/34/Lin'}],
#    'geo': [{'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000177', '@name': 'Indien', '@kuerzel': 'Ind'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000177', '@name': 'Indien', '@kuerzel': 'Ind'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '171773535',
#   'spiegelPlusId': '171774620',
#   'slug': 'SP-2020-027-77019',
#   'score': '5.286109',
#   'dokname': 'CODESCO-SP-2020-027-77019',
#   'ueberschrift': '70 000 Euro von Oma',
#   'oberzeile': 'Geheimdienste',
#   'abstrakt': 'Die dürftigen Beweise gegen einen angeblichen China-Spion aus Deutschland',
#   'autoren': {'autor': [{'name': 'Fidelius Schmid'},
#     {'name': 'Christoph Schult'}]},
#   'vorspann': 'Ein ehemaliger EU-Diplomat aus Deutschland wird beschuldigt, für China spioniert zu haben. Seine Anwälte vermuten hinter der Affäre einen Konflikt zweier Weltmächte.',
#   'teaserText': 'Ein ehemaliger EU-Diplomat aus Deutschland wird beschuldigt, für China spioniert zu haben. Seine Anwälte vermuten hinter der Affäre einen Konflikt zweier Weltmächte.; Die dürftigen Beweise gegen einen angeblichen China-Spion aus Deutschland; Gerhard…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '27',
#   'epaperkey': 'SP-2020-27',
#   'rubrik': 'Deutschland',
#   'channel': 'Deutschland',
#   'erscheinungsdatum': '27.06.2020',
#   'seite': '40',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': {'@id': '5003299',
#     '@name': 'Politik/Spionage, Geheimdienste/Fälle (Geo: beteiligte Länder)',
#     '@kuerzel': 'P/48/Fäl'},
#    'person': {'@id': '7554034',
#     '@name': 'Sabathil, Gerhard',
#     '@vorname': 'Gerhard',
#     '@nachname': 'Sabathil'},
#    'geo': [{'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000361', '@name': 'Europäische Union (EU)', '@kuerzel': 'EU'}]}},
#  {'id': '171667088',
#   'spiegelPlusId': '171752126',
#   'slug': 'SP-2020-026-76748',
#   'score': '7.714178',
#   'dokname': 'CODESCO-SP-2020-026-76748',
#   'ueberschrift': 'Alle gegen China',
#   'oberzeile': 'Geopolitik',
#   'abstrakt': 'China bringt durch seine aggressive Außenpolitik weite Teile der Welt gegen sich auf – steht ein neuer Kalter Krieg bevor?',
#   'autoren': {'autor': [{'name': 'Georg Fahrion'},
#     {'name': 'Christiane Hoffmann'},
#     {'name': 'Laura Höflinger'},
#     {'name': 'Peter Müller'},
#     {'name': 'Jörg Schindler'},
#     {'name': 'Bernhard Zand'}]},
#   'vorspann': 'Rücksichtslos dehnt Peking seine Macht aus. Nun wächst in vielen Ländern der Widerstand – und Deutschland kommt bald eine Schlüsselrolle zu.',
#   'teaserText': 'Rücksichtslos dehnt Peking seine Macht aus. Nun wächst in vielen Ländern der Widerstand – und Deutschland kommt bald eine Schlüsselrolle zu.; China bringt durch seine aggressive Außenpolitik weite Teile der Welt gegen sich auf – steht…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '26',
#   'epaperkey': 'SP-2020-26',
#   'rubrik': 'Ausland',
#   'channel': 'Ausland',
#   'erscheinungsdatum': '20.06.2020',
#   'seite': '70',
#   'wordcount': '2399',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5002715',
#      '@name': 'Militär/Finanzen, Haushalt',
#      '@kuerzel': 'M/4'},
#     {'@id': '5002545', '@name': 'Militär/Allgemeines', '@kuerzel': 'M/1'},
#     {'@id': '5002930',
#      '@name': 'Politik/Außenpolitik/Linie',
#      '@kuerzel': 'P/34/Lin'},
#     {'@id': '5002636',
#      '@name': 'Militär/Auslandsbeziehungen',
#      '@kuerzel': 'M/34'},
#     {'@id': '5002938',
#      '@name': 'Politik/Außenpolitik/Beziehungen zu Staaten/Zwischenfälle',
#      '@kuerzel': 'P/34/Staa/Zw'}],
#    'geo': [{'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000154', '@name': 'Japan', '@kuerzel': 'Ja'},
#     {'@id': '6000177', '@name': 'Indien', '@kuerzel': 'Ind'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000245', '@name': 'Australien', '@kuerzel': 'Aus'},
#     {'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000154', '@name': 'Japan', '@kuerzel': 'Ja'},
#     {'@id': '6000177', '@name': 'Indien', '@kuerzel': 'Ind'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000245', '@name': 'Australien', '@kuerzel': 'Aus'}]}},
#  {'id': '171667072',
#   'slug': 'SP-2020-026-76407',
#   'score': '6.6307707',
#   'dokname': 'CODESCO-SP-2020-026-76407',
#   'ueberschrift': 'China lädt auf',
#   'oberzeile': 'Batterien',
#   'autoren': {'autor': {'name': 'AJU'}},
#   'teaserText': '• Ende des Jahrzehnts werden voraussichtlich fast drei von vier Lithium-Ionen-Batterien, zentrales Speichermedium für Elektroautos, aus chinesischer Produktion stammen. Nach Schätzung der Londoner Analysefirma Benchmark Minerals werden bis zum…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '26',
#   'epaperkey': 'SP-2020-26',
#   'rubrik': 'Meldung Wirtschaft',
#   'channel': 'Meldung Wirtschaft',
#   'erscheinungsdatum': '20.06.2020',
#   'seite': '52',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5001068',
#      '@name': 'Technik/Kraftfahrzeugtechnik/Elektrik',
#      '@kuerzel': 'T/74/Eli'},
#     {'@id': '5001067',
#      '@name': 'Technik/Kraftfahrzeugtechnik/Elektroautos',
#      '@kuerzel': 'T/74/Ele'},
#     {'@id': '7021581',
#      '@name': 'Wirtschaft/Industrie/Branchen/Elektrotechnik/Batterien',
#      '@kuerzel': 'W/6/Bra/Ele/Bat'}],
#    'geo': [{'@id': '6000176', '@name': 'Internationales', '@kuerzel': 'I'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '171667102',
#   'spiegelPlusId': '171671841',
#   'slug': 'SP-2020-026-75593',
#   'score': '4.7059526',
#   'dokname': 'CODESCO-SP-2020-026-75593',
#   'ueberschrift': 'Weltkrieg im Labor',
#   'oberzeile': 'Pandemie',
#   'abstrakt': 'Der weltweite Kampf um einen Impfstoff, den es noch gar nicht gibt',
#   'autoren': {'autor': [{'name': 'Marco Evers'},
#     {'name': 'Georg Fahrion'},
#     {'name': 'Veronika Hackenbroch'},
#     {'name': 'Laura Höflinger'},
#     {'name': 'Kerstin Kullmann'},
#     {'name': 'Raniah Salloum'},
#     {'name': 'Alexander Sarovic'},
#     {'name': 'Cornelia Schmergal'},
#     {'name': 'Alexander Smoltczyk'}]},
#   'vorspann': 'Zwischen den USA und China eskaliert der milliardenteure Forschungswettlauf um einen Impfstoff gegen das Virus. Die hart geführte Auseinandersetzung kann über das Schicksal ganzer Völker entscheiden. Wie sähe eine gerechte Verteilung der Vakzine aus?',
#   'teaserText': 'Zwischen den USA und China eskaliert der milliardenteure Forschungswettlauf um einen Impfstoff gegen das Virus. Die hart geführte Auseinandersetzung kann über das Schicksal ganzer Völker entscheiden. Wie sähe eine gerechte Verteilung der Vakzine…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '26',
#   'epaperkey': 'SP-2020-26',
#   'rubrik': 'Wissen Coronakrise',
#   'channel': 'Wissen Coronakrise',
#   'erscheinungsdatum': '20.06.2020',
#   'seite': '90',
#   'wordcount': '4960',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': {'@id': '5001440',
#     '@name': 'Forschung, Wissenschaft/Medizin/Präventivmedizin',
#     '@kuerzel': 'FW/100/Prä'},
#    'eigenname': {'@id': '8683183', '@name': 'Corona-Krise'},
#    'geo': [{'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000176', '@name': 'Internationales', '@kuerzel': 'I'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000176', '@name': 'Internationales', '@kuerzel': 'I'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '171426710',
#   'spiegelPlusId': '171429019',
#   'slug': 'SP-2020-024-75887',
#   'score': '4.7059526',
#   'dokname': 'CODESCO-SP-2020-024-75887',
#   'ueberschrift': 'Jeder für sich',
#   'oberzeile': 'Handelsmächte',
#   'abstrakt': 'China kommt langsam aus der Krise – wird aber die Weltwirtschaft nicht retten können',
#   'autoren': {'autor': {'name': 'Georg Fahrion'}},
#   'vorspann': 'Mit gigantischen Investitionen hat China die Welt 2008 aus der Finanzkrise gezogen. Doch in der Pandemie fällt das Riesenland als globale Wachstumslokomotive aus. Es hat mit sich selbst genug zu tun – und der aktuelle Aufschwung ist zerbrechlich.',
#   'teaserText': 'Mit gigantischen Investitionen hat China die Welt 2008 aus der Finanzkrise gezogen. Doch in der Pandemie fällt das Riesenland als globale Wachstumslokomotive aus. Es hat mit sich selbst genug zu tun – und der aktuelle Aufschwung ist…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '24',
#   'epaperkey': 'SP-2020-24',
#   'rubrik': 'Wirtschaft Coronakrise',
#   'channel': 'Wirtschaft Coronakrise',
#   'erscheinungsdatum': '06.06.2020',
#   'seite': '72',
#   'wordcount': '2573',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '7008289',
#      '@name': 'Wirtschaft/Unternehmen, Betriebe/Unternehmer, Arbeitgeber, Manager/Ausländische Manager',
#      '@kuerzel': 'W/7/Unt/Ausl'},
#     {'@id': '5004322',
#      '@name': 'Wirtschaft/Gesamtwirtschaft/Lage',
#      '@kuerzel': 'W/12/Lag'},
#     {'@id': '5004327',
#      '@name': 'Wirtschaft/Gesamtwirtschaft/Politik',
#      '@kuerzel': 'W/12/Pol'},
#     {'@id': '5002930',
#      '@name': 'Politik/Außenpolitik/Linie',
#      '@kuerzel': 'P/34/Lin'}],
#    'eigenname': {'@id': '8683183', '@name': 'Corona-Krise'},
#    'geo': [{'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '171168318',
#   'spiegelPlusId': '171169903',
#   'slug': 'SP-2020-023-75721',
#   'score': '4.604875',
#   'dokname': 'CODESCO-SP-2020-023-75721',
#   'ueberschrift': 'Zwischen den Fronten',
#   'oberzeile': 'Außenpolitik',
#   'abstrakt': 'Deutschland und die EU suchen ihre neue Rolle im Ringen der Supermächte USA und China',
#   'autoren': {'autor': [{'name': 'Christiane Hoffmann'},
#     {'name': 'Peter Müller'},
#     {'name': 'Christoph Schult'},
#     {'name': 'Gerald Traufetter'}]},
#   'vorspann': 'Die Spannungen zwischen den USA und China wachsen. Europa und Deutschland müssen sich positionieren. Kanzlerin Angela Merkel will die EU-Ratspräsidentschaft für eine Annäherung an Peking nutzen – die ist aber zunehmend umstritten.',
#   'teaserText': 'Die Spannungen zwischen den USA und China wachsen. Europa und Deutschland müssen sich positionieren. Kanzlerin Angela Merkel will die EU-Ratspräsidentschaft für eine Annäherung an Peking nutzen – die ist aber zunehmend umstritten.; Deutschland…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '23',
#   'epaperkey': 'SP-2020-23',
#   'rubrik': 'Deutschland',
#   'channel': 'Deutschland',
#   'erscheinungsdatum': '30.05.2020',
#   'seite': '26',
#   'wordcount': '2748',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5002937',
#      '@name': 'Politik/Außenpolitik/Beziehungen zu Staaten/Allgemeines und Sonstiges',
#      '@kuerzel': 'P/34/Staa/So'},
#     {'@id': '5003204',
#      '@name': 'Politik/Regierung/Präsident/Allgemeines und Sonstiges',
#      '@kuerzel': 'P/45/Prä/So'},
#     {'@id': '7008772',
#      '@name': 'Gesellschaft/Bevölkerung/Umfragen',
#      '@kuerzel': 'G/433/Umf'},
#     {'@id': '7021642',
#      '@name': 'Politik/Außenpolitik/Image',
#      '@kuerzel': 'P/34/Ima'},
#     {'@id': '5004740',
#      '@name': 'Wirtschaft/Handel/Außenhandel/Außenhandelsbeziehungen',
#      '@kuerzel': 'W/5/Auss/Bez'}],
#    'person': {'@id': '160532',
#     '@name': 'Merkel, Angela',
#     '@vorname': 'Angela',
#     '@nachname': 'Merkel'},
#    'geo': [{'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000361', '@name': 'Europäische Union (EU)', '@kuerzel': 'EU'},
#     {'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000361', '@name': 'Europäische Union (EU)', '@kuerzel': 'EU'},
#     {'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000361', '@name': 'Europäische Union (EU)', '@kuerzel': 'EU'}]}},
#  {'id': '171168371',
#   'spiegelPlusId': '171638323',
#   'slug': 'SP-2020-023-75668',
#   'score': '4.3261166',
#   'dokname': 'CODESCO-SP-2020-023-75668',
#   'ueberschrift': 'Ende eines Experiments',
#   'oberzeile': 'China',
#   'abstrakt': 'Peking nutzt die Coronakrise, um seinen Einfluss auf Hongkong zu vergrößern',
#   'autoren': {'autor': [{'name': 'Holmes Chan'}, {'name': 'Bernhard Zand'}]},
#   'vorspann': '23 Jahre nach Hongkongs Rückgabe an China unternimmt Peking erstmals rechtliche Schritte, um die ehemalige britische Kronkolonie zu unterwerfen. Damit belebt die chinesische Führung die Protestbewegung – und fordert die USA heraus.',
#   'teaserText': '23 Jahre nach Hongkongs Rückgabe an China unternimmt Peking erstmals rechtliche Schritte, um die ehemalige britische Kronkolonie zu unterwerfen. Damit belebt die chinesische Führung die Protestbewegung – und fordert die USA heraus.; Peking…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '23',
#   'epaperkey': 'SP-2020-23',
#   'rubrik': 'Ausland',
#   'channel': 'Ausland',
#   'erscheinungsdatum': '30.05.2020',
#   'seite': '80',
#   'wordcount': '1866',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5003097',
#      '@name': 'Politik/Polizei/Recht',
#      '@kuerzel': 'P/42/Re'},
#     {'@id': '5002938',
#      '@name': 'Politik/Außenpolitik/Beziehungen zu Staaten/Zwischenfälle',
#      '@kuerzel': 'P/34/Staa/Zw'},
#     {'@id': '6001860',
#      '@name': 'Politik/Regionen/Bund-Länder-Beziehungen',
#      '@kuerzel': 'P/8/Bun'},
#     {'@id': '5003063',
#      '@name': 'Politik/Innenpolitik/Demonstrationen',
#      '@kuerzel': 'P/41/Dem'},
#     {'@id': '5004330',
#      '@name': 'Wirtschaft/Gesamtwirtschaft/Wirtschaftsräume',
#      '@kuerzel': 'W/12/Räu'}],
#    'person': {'@id': '7701730',
#     '@name': 'Xi Jinping',
#     '@nachname': 'Xi Jinping'},
#    'eigenname': {'@id': '8683183', '@name': 'Corona-Krise'},
#    'geo': [{'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000174', '@name': 'Hongkong', '@kuerzel': 'HK'},
#     {'@id': '6000229', '@name': 'China (Volksrepublik)', '@kuerzel': 'Ch-V'},
#     {'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000174', '@name': 'Hongkong', '@kuerzel': 'HK'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '171037337',
#   'slug': 'SP-2020-022-75351',
#   'score': '6.2039',
#   'dokname': 'CODESCO-SP-2020-022-75351',
#   'ueberschrift': 'Singen verboten',
#   'oberzeile': 'Analyse',
#   'abstrakt': 'Hongkongs Demokratiebewegung will wieder auf die Straße gehen',
#   'autoren': {'autor': {'name': 'Georg Fahrion'}},
#   'vorspann': 'China will die Proteste in Hongkong beenden und die Stadt unter Kontrolle bringen.',
#   'teaserText': 'China will die Proteste in Hongkong beenden und die Stadt unter Kontrolle bringen.; Hongkongs Demokratiebewegung will wieder auf die Straße gehen; • Wenn sich am 4. Juni das Pekinger Tiananmen-Massaker jährt, wird es in Hongkong zum ersten Mal…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '2020',
#   'ausgabe': '22',
#   'epaperkey': 'SP-2020-22',
#   'rubrik': 'Kolumne Ausland',
#   'channel': 'Kolumne Ausland',
#   'erscheinungsdatum': '23.05.2020',
#   'seite': '78',
#   'wordcount': '333',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'true',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '6001860',
#      '@name': 'Politik/Regionen/Bund-Länder-Beziehungen',
#      '@kuerzel': 'P/8/Bun'},
#     {'@id': '5003063',
#      '@name': 'Politik/Innenpolitik/Demonstrationen',
#      '@kuerzel': 'P/41/Dem'},
#     {'@id': '5003071',
# ...
#   'teaserText': 'Der Lange Marsch der Rotgardisten / Von Anna Louise Strong; Die Amerikanerin Anna Louise Strong, 81, lebt seit Jahren in China und ist eng mit Parteichef Mao Tse-tung befreundet. Wie Mao übt auch sie sich trotz ihres hohen Alters noch gelegentlich…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1967',
#   'ausgabe': '21',
#   'epaperkey': 'SP-1967-21',
#   'rubrik': 'Ausland',
#   'channel': 'Ausland',
#   'erscheinungsdatum': '15.05.1967',
#   'seite': '102',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '7008713',
#      '@name': 'Gesellschaft/Bevölkerung/Jugendliche/Gruppen',
#      '@kuerzel': 'G/433/Jug/Gru'},
#     {'@id': '5002824',
#      '@name': 'Politik/Allgemeines/Geschichte/Allgemeines und Sonstiges',
#      '@kuerzel': 'P/1/Ge/So'}],
#    'person': {'@id': '234761',
#     '@name': 'Strong, Anna Louise',
#     '@vorname': 'Anna Louise',
#     '@nachname': 'Strong'},
#    'geo': {'@id': '6000229',
#     '@name': 'China (Volksrepublik)',
#     '@kuerzel': 'Ch-V'}}},
#  {'id': '45293090',
#   'score': '4.705912',
#   'dokname': 'PPM-SP19670424-PPM-SP19670180140014701',
#   'ueberschrift': '„DER GENERALSEKRETAR IST EINE GROSSE GIFTPFLANZE“',
#   'unterzeile': 'Ein Bericht aus dem China der Kulturrevolution / Von Jean-Louis Vincent',
#   'vorspann': 'Seit 1964 Ist Jean-Louis Vincent Korrespondent der französischen Nachrichtenagentur „Agence France-Presse“ in Peking. Er war auch Augenzeuge der jüngsten Ereignisse in China.',
#   'teaserText': 'Ein Bericht aus dem China der Kulturrevolution / Von Jean-Louis Vincent; Seit 1964 Ist Jean-Louis Vincent Korrespondent der französischen Nachrichtenagentur „Agence France-Presse“ in Peking. Er war auch Augenzeuge der jüngsten Ereignisse…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1967',
#   'ausgabe': '18',
#   'epaperkey': 'SP-1967-18',
#   'rubrik': 'Ausland',
#   'channel': 'Ausland',
#   'erscheinungsdatum': '24.04.1967',
#   'seite': '140',
#   'wordcount': '2205',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1',
#   'deskribierungen': {'sig': {'@id': '5002824',
#     '@name': 'Politik/Allgemeines/Geschichte/Allgemeines und Sonstiges',
#     '@kuerzel': 'P/1/Ge/So'},
#    'person': [{'@id': '153128',
#      '@name': 'Mao Zedong',
#      '@nachname': 'Mao Zedong'},
#     {'@id': '249573',
#      '@name': 'Vincent, Jean-Louis',
#      '@vorname': 'Jean-Louis',
#      '@nachname': 'Vincent'}],
#    'geo': {'@id': '6000229',
#     '@name': 'China (Volksrepublik)',
#     '@kuerzel': 'Ch-V'}}},
#  {'id': '46437780',
#   'score': '3.427063',
#   'dokname': 'PPM-SP19670313-PPM-SP19670120122012701',
#   'ueberschrift': 'BOMBEN GEGEN CHINAS BOMBE?',
#   'autoren': {'autor': {'name': 'Karl Jaspers'}},
#   'vorspann': 'Der Philosoph Karl Jaspers, 84, erteilt den Kritikern seines Buches „Wohin treibt die Bundesrepublik?“ (SPIEGEL 17 -- 19/1966) eine „Antwort“, die demnächst im Münchner Piper-Verlag erscheint. In dem Buch, dem der folgende Auszug entnommen ist, erläutert Jaspers seine Empfehlung, China notfalls mit einem Präventivschlag zu bedrohen.',
#   'teaserText': 'Der Philosoph Karl Jaspers, 84, erteilt den Kritikern seines Buches „Wohin treibt die Bundesrepublik?“ (SPIEGEL 17 -- 19/1966) eine „Antwort“, die demnächst im Münchner Piper-Verlag erscheint. In dem Buch, dem der folgende…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1967',
#   'ausgabe': '12',
#   'epaperkey': 'SP-1967-12',
#   'rubrik': 'Ausland',
#   'channel': 'Ausland',
#   'erscheinungsdatum': '13.03.1967',
#   'seite': '122',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1',
#   'deskribierungen': {'sig': {'@id': '5002936',
#     '@name': 'Politik/Außenpolitik/Allgemeines und Sonstiges',
#     '@kuerzel': 'P/34/So'},
#    'person': {'@id': '7002707',
#     '@name': 'Jaspers, Karl [Philosoph]',
#     '@vorname': 'Karl',
#     '@nachname': 'Jaspers',
#     '@zusatz': 'Philosoph'},
#    'geo': [{'@id': '6000005',
#      '@name': 'Sowjetunion (UdSSR) (abgeschlossen seit 31.12.1991)',
#      '@kuerzel': 'USSR'},
#     {'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000181', '@name': 'Frankreich', '@kuerzel': 'Fr'},
#     {'@id': '6000198', '@name': 'Deutschland', '@kuerzel': 'D'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '46415539',
#   'score': '4.6649084',
#   'dokname': 'COCQEINZEL-SP19661226-C0564769',
#   'ueberschrift': '„BEI DER NPD HOFFT MAN AUF CHINA“',
#   'unterzeile': 'SPIEGEL-Interview mit dem ehemaligen Vorsitzenden der bayrischen\nNPD, Franz Florian Winter',
#   'teaserText': 'SPIEGEL-Interview mit dem ehemaligen Vorsitzenden der bayrischen\nNPD, Franz Florian Winter; Als die NPD nach den bayrischen Landtagswahlen am 20. November mit 15 Abgeordneten in das Bayern-Parlament einzog, fehlte der Führer: Kurz vor der Wahl war…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1966',
#   'ausgabe': '53',
#   'epaperkey': 'SP-1966-53',
#   'rubrik': 'Interview Deutschland',
#   'channel': 'Interview Deutschland',
#   'erscheinungsdatum': '26.12.1966',
#   'seite': '24',
#   'wordcount': '1064',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1',
#   'deskribierungen': {'sig': {'@id': '7010289',
#     '@name': 'Politik/Parteien/Einzelne Parteien/Politik/Interne Parteipolitik',
#     '@kuerzel': 'P/40/E/Pol/Int'},
#    'person': {'@id': '260924',
#     '@name': 'Winter, Franz Florian [NPD]',
#     '@vorname': 'Franz Florian',
#     '@nachname': 'Winter',
#     '@zusatz': 'NPD'},
#    'firma': {'@id': '7163190', '@name': 'NPD'},
#    'geo': {'@id': '6000252', '@name': 'Bayern', '@kuerzel': 'Bay'}}},
#  {'id': '46265824',
#   'score': '6.6303806',
#   'dokname': 'COCQEINZEL-SP19660228-C0558447',
#   'ueberschrift': 'CHINA-BOMBE.',
#   'teaserText': 'Kann Rotchina bereits Atombomben einsetzen? US -Experten sagen nein. Begründung: Den Chinesen, die im Oktober 1964 ihre erste Bombe zündeten und in jedem Monat zwei Atombomben produzieren können, fehlen die notwendigen Trägersysteme. Ein im…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1966',
#   'ausgabe': '10',
#   'epaperkey': 'SP-1966-10',
#   'rubrik': 'Panorama',
#   'channel': 'Panorama',
#   'erscheinungsdatum': '28.02.1966',
#   'seite': '14',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1'},
#  {'id': '46273211',
#   'score': '6.6303806',
#   'dokname': 'COCQEINZEL-SP19650707-C0553148',
#   'ueberschrift': 'CHINA-FREUND.',
#   'teaserText': 'Ägypten will vonRotchina Atomgeheimnisse erfahren. Eine Abordnung ägyptischer Atomforscher ist nach Peking gereist, um die Zusammenarbeit auf dem Gebiet der Kernphysik zu verbessern. Beide Länder arbeiten bereits bei der Flugzeug-Entwicklung…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1965',
#   'ausgabe': '28',
#   'epaperkey': 'SP-1965-28',
#   'rubrik': 'Panorama',
#   'channel': 'Panorama',
#   'erscheinungsdatum': '07.07.1965',
#   'seite': '14',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1'},
#  {'id': '46273261',
#   'score': '5.1763954',
#   'dokname': 'COCQEINZEL-SP19650707-C0553199',
#   'ueberschrift': '„WIR WÜRDEN CHINA BOMBARDIEREN“',
#   'unterzeile': 'Interview mit dem US-Strategen Professor Herman Kahn',
#   'teaserText': 'Interview mit dem US-Strategen Professor Herman Kahn; Der Mathematiker und Physiker Herman Kahn, 43, in den Vereinigten Staaten als „Clausewitz des Atomzeitalters“ bekannt, hat als Berater der Atomenergie-Kommission und des Pentagon…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1965',
#   'ausgabe': '28',
#   'epaperkey': 'SP-1965-28',
#   'rubrik': 'Ausland',
#   'channel': 'Ausland',
#   'erscheinungsdatum': '07.07.1965',
#   'seite': '60',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5002937',
#      '@name': 'Politik/Außenpolitik/Beziehungen zu Staaten/Allgemeines und Sonstiges',
#      '@kuerzel': 'P/34/Staa/So'},
#     {'@id': '6000569',
#      '@name': 'Militär/Strategie/Allgemeines und Sonstiges',
#      '@kuerzel': 'M/237/So'},
#     {'@id': '6000732',
#      '@name': 'Militär/Wehrpolitik/Allgemeines und Sonstiges',
#      '@kuerzel': 'M/41/So'}],
#    'person': {'@id': '120183',
#     '@name': 'Kahn, Herman [Futurologe]',
#     '@vorname': 'Herman',
#     '@nachname': 'Kahn',
#     '@zusatz': 'Futurologe'},
#    'geo': [{'@id': '6000005',
#      '@name': 'Sowjetunion (UdSSR) (abgeschlossen seit 31.12.1991)',
#      '@kuerzel': 'USSR'},
#     {'@id': '6000032', '@name': 'USA', '@kuerzel': 'USA'},
#     {'@id': '6000229',
#      '@name': 'China (Volksrepublik)',
#      '@kuerzel': 'Ch-V'}]}},
#  {'id': '46272239',
#   'score': '5.81386',
#   'dokname': 'COCQEINZEL-SP19650414-C0551292',
#   'ueberschrift': 'TROTZ CHINA ÜBERLEBEN?',
#   'unterzeile': 'Patrick Gordon Walker über Arnold J. Toynbee: "Die Zukunft des\nWestens"',
#   'autoren': {'autor': {'name': 'Patrick Gordon Walker'}},
#   'teaserText': 'Patrick Gordon Walker über Arnold J. Toynbee: "Die Zukunft des\nWestens"; Der englische Labourpolitiker Patrick Gordon Walker, 58, Harald Wilsons Außenminister für weniger als 100 Tage, derzeit mit einer diplomatischen Sondermission in Südostasien…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1965',
#   'ausgabe': '16',
#   'epaperkey': 'SP-1965-16',
#   'rubrik': 'Kultur',
#   'channel': 'Kultur',
#   'erscheinungsdatum': '14.04.1965',
#   'seite': '133',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1',
#   'deskribierungen': {'person': [{'@id': '243249',
#      '@name': 'Toynbee, Arnold',
#      '@vorname': 'Arnold',
#      '@nachname': 'Toynbee'},
#     {'@id': '333902',
#      '@name': 'Gordon-Walker, Patrick',
#      '@vorname': 'Patrick',
#      '@nachname': 'Gordon-Walker'}]}},
#  {'id': '46169171',
#   'score': '6.6303806',
#   'dokname': 'COCQEINZEL-SP19650203-C0549040',
#   'ueberschrift': 'CHINA-KONTAKTE.',
#   'oberzeile': 'DEUTSCHLAND',
#   'teaserText': 'Die Bundesregierung will über die rotchinesische Botschaft in Bern wieder wegen der Aufnahme regulärer Handelsbeziehungen mit Peking sondieren. Erste Kontakte im Juni letzten Jahres waren erfolglos geblieben, da die Chinesen einem Handelsabkommen…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1965',
#   'ausgabe': '6',
#   'epaperkey': 'SP-1965-6',
#   'rubrik': 'Panorama',
#   'channel': 'Panorama',
#   'erscheinungsdatum': '03.02.1965',
#   'seite': '12',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1'},
#  {'id': '46169156',
#   'score': '6.6303806',
#   'dokname': 'COCQEINZEL-SP19650120-C0549024',
#   'ueberschrift': 'CHINA-HANDEL.',
#   'oberzeile': 'AUSLAND',
#   'teaserText': 'Rotchina wird imFrühjahr zum erstenmal seit vier Jahren wieder auf der Leipziger Messe ausstellen. Die Chinesen wollen vorzugsweise Textilien anbieten und durch niedrige Preise einen Einbruch in den Weltmarkt erzielen.',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1965',
#   'ausgabe': '4',
#   'epaperkey': 'SP-1965-4',
#   'rubrik': 'Panorama',
#   'channel': 'Panorama',
#   'erscheinungsdatum': '20.01.1965',
#   'seite': '14',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1'},
#  {'id': '46176681',
#   'score': '4.245413',
#   'dokname': 'COCQEINZEL-SP19641216-C0550615',
#   'ueberschrift': '„SIE TRANKEN MENSCHENBLUT UND GIFT AUS CHINA“',
#   'unterzeile': 'SPIEGEL-Interview mit Kongo-Premier Moise Tschombé',
#   'teaserText': 'SPIEGEL-Interview mit Kongo-Premier Moise Tschombé; SPIEGEL: Glauben Sie, Herr Ministerpräsident, daß der Kongo je befriedet werden kann?TSHOMBE: Leicht wird es nicht sein. Denn die Rebellion wird von außen unterstützt. Algier und Kairo tun alles,…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1964',
#   'ausgabe': '51',
#   'epaperkey': 'SP-1964-51',
#   'rubrik': 'Interview Ausland',
#   'channel': 'Interview Ausland',
#   'erscheinungsdatum': '16.12.1964',
#   'seite': '75',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '5003061',
#      '@name': 'Politik/Innenpolitik/Bürgerkriege, Aufstände, Rebellionen, Staatsstreiche/Allgemeines und Sonstiges',
#      '@kuerzel': 'P/41/Bük/So'},
#     {'@id': '5003076',
#      '@name': 'Politik/Innenpolitik/Zwischenfälle',
#      '@kuerzel': 'P/41/Zw'}],
#    'person': {'@id': '245056',
#     '@name': 'Tshombe, Moise',
#     '@vorname': 'Moise',
#     '@nachname': 'Tshombe'},
#    'geo': {'@id': '6000127',
#     '@name': 'Kongo (Demokratische Republik, Kinshasa)',
#     '@kuerzel': 'Ko-DR'}}},
#  {'id': '46174951',
#   'score': '6.6303806',
#   'dokname': 'COCQEINZEL-SP19640819-C0545553',
#   'ueberschrift': 'CHINA-BESÄNFTIGUNG.',
#   'oberzeile': 'AUSLAND',
#   'teaserText': 'Großbritannien hat die Erregung Rotchinas über den amerikanischen Vergeltungsangriff auf Nordvietnam gedämpft. Einen Tag nach dem USGegenschlag vom 5. August versicherte der britische Geschäftsträger in Peking, Terence Garvey, dem chinesischen…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1964',
#   'ausgabe': '34',
#   'epaperkey': 'SP-1964-34',
#   'rubrik': 'Panorama',
#   'channel': 'Panorama',
#   'erscheinungsdatum': '19.08.1964',
#   'seite': '14',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1'},
#  {'id': '46174940',
#   'score': '6.6303806',
#   'dokname': 'COCQEINZEL-SP19640819-C0545542',
#   'ueberschrift': 'CHINA-KONTAKTE.',
#   'oberzeile': 'DEUTSCHLAND',
#   'teaserText': 'Bonn will nachden amerikanischen Präsidentschaftswahlen wieder mit Washington über die Aufnahme deutscher Kontakte zu Rotchina sprechen. Wie erst jetzt bekannt wurde, haben Bundeskanzler Erhard und Außenminister Schröder bei ihrem letzten Besuch in…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1964',
#   'ausgabe': '34',
#   'epaperkey': 'SP-1964-34',
#   'rubrik': 'Panorama',
#   'channel': 'Panorama',
#   'erscheinungsdatum': '19.08.1964',
#   'seite': '12',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1'},
#  {'id': '46174956',
#   'score': '4.6649084',
#   'dokname': 'COCQEINZEL-SP19640812-C0545558',
#   'ueberschrift': '„NIEMAND KANN CHINA BESETZEN“',
#   'unterzeile': 'Wie Peking über den Krieg denkt',
#   'teaserText': 'Wie Peking über den Krieg denkt; Über eine Stunde lang unterhielt sich der Chefredakteur des Wiener „Kurier“, Dr. Hugo Portisch, Ende Juli mit Chinas Außenminister, Marschall Tschen Ji, über die Lage in Südostasien. Dem offiziellen…',
#   'quelle': {'id': '1001922', 'kuerzel': 'SP', 'name': 'DER SPIEGEL'},
#   'jahrgang': '1964',
#   'ausgabe': '33',
#   'epaperkey': 'SP-1964-33',
#   'rubrik': 'Ausland',
#   'channel': 'Ausland',
#   'erscheinungsdatum': '12.08.1964',
#   'seite': '47',
#   'lang': 'de',
#   'laterpay': 'false',
#   'aktuell': 'false',
#   'jung': 'false',
#   'preis': '-1',
#   'deskribierungen': {'sig': [{'@id': '6000569',
#      '@name': 'Militär/Strategie/Allgemeines und Sonstiges',
#      '@kuerzel': 'M/237/So'},
#     {'@id': '6000732',
#      '@name': 'Militär/Wehrpolitik/Allgemeines und Sonstiges',
#      '@kuerzel': 'M/41/So'}],
#    'person': {'@id': '244815', '@name': 'Tschen Ji', '@nachname': 'Tschen Ji'},
#    'geo': {'@id': '6000229',
#     '@name': 'China (Volksrepublik)',
#     '@kuerzel': 'Ch-V'}}},
#  ...]

# %% [markdown]
# ## 建立数据表格用于存储完整数据

# %%
myData = pd.DataFrame()

# %%
new_columns = []
myData.insert(0,'Index',new_columns)
myData.insert(1,'Id',new_columns)
myData.insert(2,'Erscheinungsdatum',new_columns)
myData.insert(3,'Überschrift',new_columns)
myData.insert(4,'Vorspann',new_columns)
myData.insert(5,'Channel',new_columns)
myData.insert(6,'Seite',new_columns)
myData.insert(7,'Epaperkey',new_columns)
myData.insert(8,'Score',new_columns)
myData.insert(9,'Text',new_columns)

# %% [markdown]
# ## 爬取每篇文章的正文内容，并将每篇文章的相关数据存储进入数据表格

# %%
for i in range(len(data)):
    print("正在下载第" + str(i+1) + "行")
    text_url = "https://www.spiegel.de/spiegel/print/d-"+data[i]["id"]+".html"
    headers = {
        "User-Agent": UserAgent().chrome
    }

    try:
        request = Request(text_url, headers=headers)
        response = urlopen(request)
        info = response.read().decode()
        pattern = re.compile(r'&[^;]+;',re.S)
        info = pattern.sub('', info)

        soup = BeautifulSoup(info, "html.parser")
        text = soup.get_text()
        text = text.replace('\n', '')
    except:
        text = ""
        pass
    
    newInfo = list()
    newInfo.append(str(i+1))
    if "id" in data[i]:
        newInfo.append(data[i]["id"])
    else:
        newInfo.append("")
    
    if "erscheinungsdatum" in data[i]:
        newInfo.append(data[i]["erscheinungsdatum"])
    else:
        newInfo.append("")
        
    if "ueberschrift" in data[i]:
        newInfo.append(data[i]["ueberschrift"])
    else:
        newInfo.append("")
    
    if "vorspann" in data[i]:
        newInfo.append(data[i]["vorspann"])
    elif "teaserText" in data[i]:
        newInfo.append(data[i]["teaserText"])
    else:
        newInfo.append("")
        
    if "channel" in data[i]:
        newInfo.append(data[i]["channel"])
    else:
        newInfo.append("")
        
    if "seite" in data[i]:
        newInfo.append(data[i]["seite"])
    else:
        newInfo.append("")
        
    if "epaperkey" in data[i]:
        newInfo.append(data[i]["epaperkey"])
    else:
        newInfo.append("")
        
    if "score" in data[i]:
        newInfo.append(data[i]["score"])
    else:
        newInfo.append("")
        
    newInfo.append(text)
    
    myData.loc[i]= newInfo
# Out:
# 正在下载第1行
# 正在下载第2行
# 正在下载第3行
# 正在下载第4行
# 正在下载第5行
# 正在下载第6行
# 正在下载第7行
# 正在下载第8行
# 正在下载第9行
# 正在下载第10行
# 正在下载第11行
# 正在下载第12行
# 正在下载第13行
# 正在下载第14行
# 正在下载第15行
# 正在下载第16行
# 正在下载第17行
# 正在下载第18行
# 正在下载第19行
